# %% [markdown]
# <a href="https://colab.research.google.com/github/AswiniSivadasan/DSA_Assignments/blob/main/ICTAK_DSA_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading dataset
iris=pd.read_excel('/content/iris.xls')

# %%
#Display columns
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#Display column header names
iris.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
# mean of first column of the dataset.
iris['SL'].mean()
# Out:
# 5.843333333333334

# %%
# mean of second column of the dataset.
iris['SW'].mean()
# Out:
# 3.0540000000000003

# %%
# mean of third column of the dataset.
iris['PL'].mean()
# Out:
# 3.758666666666666

# %%
# mean of fourth column of the dataset.
iris['PW'].mean()
# Out:
# 1.1986666666666668

# %%
#To check whether there is any null values in dataset
iris.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
#To check whether there is any null values in dataset
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#BOXPLOT OF SEPALLENGTH & SEPALWIDTH
sns.boxplot(x='SL',y='SW',data=iris)
# Out:
# <Axes: xlabel='SL', ylabel='SW'>

# %%
#JOINTPLOT OF SEPALLENGTH & SEPALWIDTH
sns.jointplot(x="SL",y="SW",data=iris)

# %%
#VIOLINPLOT OF SEPALLENGTH & SEPALWIDTH
sns.violinplot(x='SL',y='SW',data=iris)
# Out:
# <Axes: xlabel='SL', ylabel='SW'>

# %%
#PAIRPLOT
sns.pairplot(iris,hue='Classification',size=4)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#STRIPPLOT OF CLASSIFICATION & PL
ax=sns.stripplot(x='Classification',y='PL',data=iris,jitter=True,edgecolor='red')
